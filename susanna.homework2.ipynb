# %%
from __future__ import division
mylist=input("Please input numbers seperated by comma")
def mean(mylist):
    return sum(mylist)/len(mylist)
print mean(mylist)
# Out:
# Please input numbers seperated by comma15,20,25,30
# 22.5

# %%
from __future__ import division
list=input("please input some numbers seperated by comma")
n_of_o=input("please input number of occurancies")
def avg(list):
    return sum(list[len(list)-n_of_o:])/n_of_o
print avg(list)
# Out:
# please input some numbers seperated by comma2,4,6,8,10
# please input number of occurancies2
# 9.0

# %%
import random
a=random.randint(1,100)
print a
def function(a):
        if a<100 and a>50:
            return "Win"
        elif a<=50 and a>=1:
            return "Loss"
        elif a==100:
            return "Draw"
print function(a)
# Out:
# 35
# Loss

# %%
import pandas_datareader.data as web

# %%
list2=[web.DataReader("SBUX","google"),web.DataReader("NFLX","google"),web.DataReader("NKE","google")]
for stock in list2:
    print stock.head(7)
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  11.64  11.66  11.46  11.52  16369892
# 2010-01-05  11.48  12.00  11.44  11.80  30062592
# 2010-01-06  11.74  11.81  11.63  11.71  14210424
# 2010-01-07  11.64  11.76  11.60  11.68  10257208
# 2010-01-08  11.60  11.80  11.60  11.64  10276902
# 2010-01-11  11.68  11.68  11.44  11.60  11391606
# 2010-01-12  11.45  11.60  11.25  11.41  15429414
#             Open  High   Low  Close    Volume
# Date
# 2010-01-04  7.93  7.96  7.57   7.64  17240076
# 2010-01-05  7.65  7.66  7.26   7.36  23753443
# 2010-01-06  7.36  7.67  7.20   7.62  23294558
# 2010-01-07  7.73  7.76  7.46   7.49   9955204
# 2010-01-08  7.50  7.74  7.47   7.61   8180697
# 2010-01-11  7.66  7.70  7.53   7.60   6783308
# 2010-01-12  7.53  7.58  7.45   7.48   6329505
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  16.52  16.52  16.28  16.34  11972588
# 2010-01-05  16.28  16.45  16.18  16.40   6275456
# 2010-01-06  16.35  16.42  16.24  16.30  13399228
# 2010-01-07  16.28  16.50  16.26  16.46   7187644
# 2010-01-08  16.45  16.46  16.24  16.43   7249636
# 2010-01-11  16.48  16.48  16.16  16.23  10678264
# 2010-01-12  16.15  16.28  16.07  16.20  11485716

# %%
import matplotlib.pyplot as plt

# %%
for stock in list2:
    plt.plot(stock)
    plt.show()
